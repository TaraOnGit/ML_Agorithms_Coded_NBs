# %%
import numpy as np
import pandas as pd

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

# %%
df = pd.read_csv('/content/titanic_data.csv')
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df =df.drop(columns=['Name','Ticket','Cabin'])
df.head(2)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C

# %%
y = df['Survived']
X = df.drop(columns=['Survived'],axis=1)

# %%
X.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Embarked         2
# dtype: int64

# %%
X_cols = X.columns
X_cols
# Out:
# Index(['PassengerId', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
cat_cols = X.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['Sex', 'Embarked'], dtype='object')

# %%
num_cols = X.select_dtypes(include='number').columns
num_cols
# Out:
# Index(['PassengerId', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
impute = SimpleImputer(strategy='most_frequent')
X = pd.DataFrame(impute.fit_transform(X))
X.columns = X_cols
X.head(2)
# Out:
#   PassengerId Pclass     Sex   Age SibSp Parch     Fare Embarked
# 0           1      3    male  22.0     1     0     7.25        S
# 1           2      1  female  38.0     1     0  71.2833        C

# %%
X.isna().sum()
# Out:
# PassengerId    0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
transformer = ColumnTransformer(
    transformers = [
        ('ohe',OneHotEncoder(drop='first'),cat_cols),
        ('scaler',StandardScaler(),num_cols)
    ]
)

# %%
X_transformed = transformer.fit_transform(X)

# %%
transformer
# Out:
# ColumnTransformer(transformers=[('ohe', OneHotEncoder(drop='first'),
#                                  Index(['Sex', 'Embarked'], dtype='object')),
#                                 ('scaler', StandardScaler(),
#                                  Index(['PassengerId', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object'))])

# %%
parameters = {
    'criterion' : ['gini','entropy'],
    'splitter' : ['best','random'],
    'max_depth' : [2,3,4,5]
}

# %%
grid = GridSearchCV(DecisionTreeClassifier(),parameters,cv=5)

# %%
best_params = grid.fit(X_transformed,y)

# %%
best_params
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 4, 5],
#                          'splitter': ['best', 'random']})

# %%
X_train,X_test,y_train,y_test = train_test_split(X_transformed,y,test_size=0.2,random_state=42)

# %%
dtc = DecisionTreeClassifier(criterion='entropy',max_depth=4,splitter='best')
dtc.fit(X_train,y_train)
y_pred = dtc.predict(X_test)

# %%
X.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
plot_tree(dtc,class_names=['0','1'],filled=True)
# Out:
# [Text(0.5089285714285714, 0.9, 'x[0] <= 0.5\nentropy = 0.955\nsamples = 712\nvalue = [444, 268]\nclass = 0'),
#  Text(0.2857142857142857, 0.7, 'x[4] <= 0.229\nentropy = 0.829\nsamples = 245\nvalue = [64, 181]\nclass = 1'),
#  Text(0.39732142857142855, 0.8, 'True  '),
#  Text(0.14285714285714285, 0.5, 'x[3] <= -0.564\nentropy = 0.235\nsamples = 130\nvalue = [5, 125]\nclass = 1'),
#  Text(0.07142857142857142, 0.3, 'x[5] <= -1.976\nentropy = 0.513\nsamples = 35\nvalue = [4, 31]\nclass = 1'),
#  Text(0.03571428571428571, 0.1, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = 0'),
#  Text(0.10714285714285714, 0.1, 'entropy = 0.431\nsamples = 34\nvalue = [3, 31]\nclass = 1'),
#  Text(0.21428571428571427, 0.3, 'x[8] <= 2.243\nentropy = 0.084\nsamples = 95\nvalue = [1, 94]\nclass = 1'),
#  Text(0.17857142857142858, 0.1, 'entropy = 0.0\nsamples = 82\nvalue = [0, 82]\nclass = 1'),
#  Text(0.25, 0.1, 'entropy = 0.391\nsamples = 13\nvalue = [1, 12]\nclass = 1'),
#  Text(0.42857142857142855, 0.5, 'x[8] <= -0.178\nentropy = 1.0\nsamples = 115\nvalue = [59.0, 56.0]\nclass = 0'),
#  Text(0.35714285714285715, 0.3, 'x[2] <= 0.5\nentropy = 0.979\nsamples = 94\nvalue = [39, 55]\nclass = 1'),
#  Text(0.32142857142857145, 0.1, 'entropy = 0.858\nsamples = 39\nvalue = [11, 28]\nclass = 1'),
#  Text(0.39285714285714285, 0.1, 'entropy = 1.0\nsamples = 55\nvalue = [28.0, 27.0]\nclass = 0'),
#  Text(0.5, 0.3, 'x[5] <= -1.749\nentropy = 0.276\nsamples = 21\nvalue = [20, 1]\nclass = 0'),
#  Text(0.4642857142857143, 0.1, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.5357142857142857, 0.1, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0]\nclass = 0'),
#  Text(0.7321428571428571, 0.7, 'x[5] <= -1.673\nentropy = 0.694\nsamples = 467\nvalue = [380, 87]\nclass = 0'),
#  Text(0.6205357142857142, 0.8, '  False'),
#  Text(0.6071428571428571, 0.5, 'x[6] <= 1.794\nentropy = 0.902\nsamples = 22\nvalue = [7.0, 15.0]\nclass = 1'),
#  Text(0.5714285714285714, 0.3, 'entropy = 0.0\nsamples = 14\nvalue = [0, 14]\nclass = 1'),
#  Text(0.6428571428571429, 0.3, 'x[5] <= -1.976\nentropy = 0.544\nsamples = 8\nvalue = [7, 1]\nclass = 0'),
#  Text(0.6071428571428571, 0.1, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]\nclass = 0'),
#  Text(0.6785714285714286, 0.1, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]\nclass = 0'),
#  Text(0.8571428571428571, 0.5, 'x[4] <= -0.968\nentropy = 0.639\nsamples = 445\nvalue = [373, 72]\nclass = 0'),
#  Text(0.7857142857142857, 0.3, 'x[3] <= -0.329\nentropy = 0.915\nsamples = 91\nvalue = [61.0, 30.0]\nclass = 0'),
#  Text(0.75, 0.1, 'entropy = 0.625\nsamples = 32\nvalue = [27, 5]\nclass = 0'),
#  Text(0.8214285714285714, 0.1, 'entropy = 0.983\nsamples = 59\nvalue = [34, 25]\nclass = 0'),
#  Text(0.9285714285714286, 0.3, 'x[3] <= 0.527\nentropy = 0.525\nsamples = 354\nvalue = [312, 42]\nclass = 0'),
#  Text(0.8928571428571429, 0.1, 'entropy = 0.605\nsamples = 223\nvalue = [190, 33]\nclass = 0'),
#  Text(0.9642857142857143, 0.1, 'entropy = 0.361\nsamples = 131\nvalue = [122, 9]\nclass = 0')]
