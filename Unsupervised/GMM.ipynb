# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_blobs
from sklearn.mixture import GaussianMixture

# %%
X,y_true = make_blobs(n_samples=400,centers=4,n_features=2,cluster_std=0.70,random_state=0)

# %%
X.shape, y_true.shape
# Out:
# ((400, 2), (400,))

# %%
plt.scatter(X[:,0],X[:,1])
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
# Out:
# Text(0, 0.5, 'Feature 2')

# %%
gmm = GaussianMixture(n_components=4,random_state=42)
gmm.fit(X)
labels = gmm.predict(X)

# %%
plt.scatter(X[:,0],X[:,1],c=labels)
centers = gmm.means_
plt.scatter(centers[:,0],centers[:,1],c='blue',s=200,marker='+')

# %%
gmm.converged_
# Out:
# True

# %%
gmm.n_iter_
# Out:
# 3

# %%
gmm.covariances_
# Out:
# array([[[ 0.48521696,  0.01601096],
#         [ 0.01601096,  0.52350329]],
#
#        [[ 0.37350771,  0.03585121],
#         [ 0.03585121,  0.48699208]],
#
#        [[ 0.45867925, -0.01885801],
#         [-0.01885801,  0.38463026]],
#
#        [[ 0.5341825 ,  0.01361759],
#         [ 0.01361759,  0.60998661]]])

# %%
gmm.means_
# Out:
# array([[-1.67724462,  2.81173449],
#        [-1.2948052 ,  7.76097509],
#        [ 1.9520737 ,  0.81024547],
#        [ 0.88707207,  4.34182225]])

# %%
gmm.weights_
# Out:
# array([0.23985515, 0.24668536, 0.24663184, 0.26682765])

# %%
#Hard Clustering
gmm.predict(X)
# Out:
# array([3, 0, 0, 3, 0, 1, 2, 3, 0, 2, 1, 2, 3, 0, 0, 2, 0, 2, 3, 0, 0, 0,
#        1, 3, 3, 1, 1, 3, 3, 2, 3, 3, 0, 3, 0, 1, 2, 3, 2, 3, 0, 1, 2, 3,
#        2, 1, 2, 2, 2, 1, 1, 1, 0, 1, 1, 0, 3, 2, 2, 0, 2, 2, 2, 2, 3, 0,
#        2, 3, 0, 1, 0, 3, 0, 1, 2, 0, 3, 0, 1, 0, 0, 3, 2, 1, 3, 0, 0, 3,
#        0, 2, 0, 2, 3, 0, 0, 1, 3, 2, 2, 2, 1, 2, 3, 3, 0, 1, 3, 1, 2, 0,
#        0, 0, 3, 0, 1, 2, 1, 0, 1, 1, 3, 0, 2, 1, 3, 1, 2, 2, 2, 3, 1, 1,
#        1, 0, 3, 0, 1, 3, 1, 0, 3, 0, 0, 1, 0, 2, 3, 0, 2, 0, 2, 3, 2, 3,
#        1, 0, 2, 0, 0, 0, 3, 0, 1, 0, 0, 1, 2, 2, 0, 1, 1, 1, 1, 2, 2, 2,
#        3, 0, 3, 1, 3, 1, 0, 3, 1, 0, 1, 3, 3, 1, 3, 3, 1, 0, 1, 1, 1, 2,
#        2, 3, 3, 0, 2, 2, 1, 3, 0, 1, 3, 1, 3, 3, 2, 2, 1, 2, 3, 1, 2, 1,
#        0, 3, 1, 0, 3, 0, 2, 1, 3, 1, 3, 0, 3, 3, 1, 2, 0, 2, 3, 0, 2, 3,
#        3, 1, 2, 3, 1, 3, 2, 0, 0, 2, 0, 3, 1, 1, 3, 3, 2, 1, 3, 0, 0, 0,
#        1, 3, 3, 3, 3, 3, 2, 3, 3, 1, 0, 2, 1, 2, 2, 2, 1, 2, 2, 1, 1, 1,
#        2, 3, 2, 3, 2, 0, 3, 2, 0, 3, 2, 2, 3, 0, 1, 1, 3, 1, 2, 2, 3, 1,
#        1, 2, 2, 3, 1, 3, 2, 3, 2, 1, 0, 0, 2, 0, 3, 0, 0, 1, 0, 1, 2, 0,
#        1, 2, 1, 3, 0, 3, 0, 2, 3, 2, 1, 2, 2, 2, 2, 1, 2, 0, 2, 0, 2, 3,
#        1, 3, 2, 2, 3, 0, 0, 1, 1, 1, 0, 3, 2, 3, 0, 2, 0, 1, 0, 3, 3, 0,
#        1, 3, 1, 1, 0, 1, 0, 1, 3, 3, 3, 3, 1, 1, 1, 1, 0, 1, 3, 2, 2, 3,
#        3, 2, 3, 2])

# %%
#Soft Clustering
gmm.predict_proba(X)
# Out:
# array([[3.33558911e-06, 2.24022523e-02, 1.05520868e-16, 9.77594412e-01],
#        [9.99999443e-01, 2.43213672e-13, 3.13826357e-12, 5.56522253e-07],
#        [9.99999094e-01, 1.15166479e-10, 2.64586043e-14, 9.05401047e-07],
#        ...,
#        [4.94425462e-06, 2.40665214e-28, 9.99979598e-01, 1.54574260e-05],
#        [9.52752847e-02, 7.26397968e-13, 3.07750893e-03, 9.01647206e-01],
#        [9.75081752e-11, 5.33534993e-38, 9.99999979e-01, 2.09900418e-08]])
